# %% [markdown]
# print
# return

# %%
def make_student(name,age):
  return{"name":name,"age":age}

s = make_student("ahmed",20)
print(s)
# Out:
# {'name': 'ahmed', 'age': 20}

# %%
students = [
    {"name":"ali","age":21},
    {"name":"mohamed","age":22}
]

for s in students:
  print(s["name"],"-",s["age"])
# Out:
# ali - 21
# mohamed - 22

# %%
total = 0
for s in students:
  total += s["age"]
print("میانگین:",total/len(students))
# Out:
# میانگین: 21.5

# %%
adults =[s for s in students if s["age"]>=21]
print(adults)
# Out:
# [{'name': 'ali', 'age': 21}, {'name': 'mohamed', 'age': 22}]

# %%
try:
  age = int(input("سن:"))
except:
   print("یک عدد وارد کن")
# Out:
# سن:23

# %%
class Student:
  def __init__(self,name,grade):
    self.name = name
    self.age = age

s = Student("ali",21)
print(s.name,"-",s.age)
# Out:
# ali - 23

# %% [markdown]
# **pandas**

# %%
import pandas as pd

data = pd.DataFrame(students)

print(data)
# Out:
#       name  age
# 0      ali   21
# 1  mohamed   22

# %%
df = pd.read_csv("data.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_12485/3562840662.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("data.csv")
#       2 print(df)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/sample_data/california_housing_train.csv")


print(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
import matplotlib.pyplot as plt
plt.plot(df["longitude"],df["housing_median_age"])
plt.show()

# %% [markdown]
# scikit-learn

# %%
from sklearn.linear_model import LinearRegression

model =LinearRegression()

model.fit("latitude","total_rooms")

print (model.predict([[2]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_12485/2784554011.py in <cell line: 0>()
#       3 model =LinearRegression()
#       4
# ----> 5 model.fit("latitude","total_rooms")
#       6
#       7 print (model.predict([[2]]))
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
#     603             X,
#
# ...
