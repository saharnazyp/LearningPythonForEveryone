# %% [markdown]
# *توابع*

# %%
def say_hello():
    print("سلام")

# %%
say_hello()
# Out:
# سلام

# %%
def welcome():
    print("به کلاس پایتون خوش آمدید")

welcome()
# Out:
# به کلاس پایتون خوش آمدید

# %%
name= "sara"

# %%
def say_hello(name):
    print("hello",name)

# %%
say_hello("sara")
# Out:
# hello sara

# %%
def add (a,b):
    print(a+b)

# %%
add(5,3)
# Out:
# 8

# %% [markdown]
# Return

# %%
def add(a,b):
    return a+b

# %%
result = add (4,6)
print(result)
# Out:
# 10

# %% [markdown]
# *تمرین*
# یک تابع بساز به نام
#
# say_name
#
# که اسم را بگیرد و چاپ کند
# مثال خرجی باید بشه : اسم شما علی است

# %% [markdown]
# تمرین 2:
#
# یک تابع بساز به نام :
#
#
# square
#
#
# که عدد بگیرد و مجذورش را چاپ کند
#
# مثال :
#
# square (4)
#
# خروجی:
#
# 16
#
# *تمرین3*
#
# یک تابع بساز:
#
# person_info
#
#
# ورودی ها :
# name
# age
# city,
#
#
# و با printچاپ کند
#
#
# نام:...
# سن:...
# شهر:...

# %% [markdown]
# # *INPUT*
#
#
# یعنی از کاربر چیزی بگیر

# %%
name = input("اسم خود را وارد کنید: ")
print(name)
# Out:
# اسم خود را وارد کنید:  Sara
# Sara

# %%
print(name)
# Out:
# Sara

# %%
name = input("نام شما چیست؟ ")
age = input("سن شما چند است؟ ")

print("نام:", name)
print("سن:", age)
# Out:
# نام شما چیست؟  ema
# سن شما چند است؟  22
# نام: ema
# سن: 22

# %%
age = int(input("سن خود را وارد کنید: "))
print(age + 5)
# Out:
# سن خود را وارد کنید:  20
# 25

# %%
a = int(input("عدد اول: "))
b = int(input("عدد دوم: "))

print(a + b)
# Out:
# عدد اول:  120
# عدد دوم:  286
# 406

# %%
name = input("نام شما: ")
city = input("شهر شما: ")

print(name , "در شهر" , city , "زندگی می‌کند")
# Out:
# نام شما:  صبا
# شهر شما:  تهران
# صبا در شهر تهران زندگی می‌کند

# %% [markdown]
# # *تمرین*
#
# 1. از کاربر بپرس نام،سن جمله نهاییت باید مثل مثال باشه :
#    سلام آریا شما 12 سال دارید
# 2. برنامه ای بنویس که : قد و وزنم از کاربر بگیرد و چاپ کند
#    قد:
#    وزن:
# 3. از کاربر دو عدد بگیر و چاپ کن

# %% [markdown]
# پروژه:
# مدت زمان تحویل 1 ماه
# 1. ماشین حساب ساده
# 2. بازی ساده حدس عدد
# 3. سیستم مدیریت دانشجو
